# %%
a =10

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
f = ("test.txt" ,'r')
print("this is my print")
# Out:
# this is my print

# %%
try :
    f = open("test.txt" ,'r')

except Exception as e :
    print("this is my except block" ,e)

a = 4+6
a
# Out:
# this is my except block [Errno 2] No such file or directory: 'test.txt'
# 10

# %%
try :
    f = open("test.txt" ,'r')
    f.write("write into my file")

except Exception as e :
    print("this is my except block" ,e)

else :
    f.close()
    print("this will be excuted once your try will excute without error")
# Out:
# this is my except block [Errno 2] No such file or directory: 'test.txt'

# %%
try :
    f = open("test1.txt" ,'r')
    f.write("write into my file")

except Exception as e :
    print("this is my except block" ,e)

else :
    f.close()
    print("this will be excuted once your try will excute without error")
# Out:
# this is my except block [Errno 2] No such file or directory: 'test1.txt'

# %%
try :
    f = open("test2.txt" ,'w')
    f.write("writing something")

finally :
    print("finally will excute itself in any situation")
# Out:
# finally will excute itself in any situation

# %% [markdown]
# ##List of General Use Exceptional Handling

# %%
#list of general exceptional handling

# %%
try:
    a = 10/0
except ZeroDivisionError as e :
    print(e)
# Out:
# division by zero

# %%
try :
    int("Pankaj")
except (ValueError ,TypeError) as e :
    print(e)
# Out:
# invalid literal for int() with base 10: 'Pankaj'

# %%
try : # to know about what type of error
    int("Pankaj")
except :
    print("this will catch an error")
# Out:
# this will catch an error

# %%
try :
    import sudh
except ImportError as e :
    print(e)
23837/989
# Out:
# No module named 'sudh'
# 24.10212335692619

# %%
try :
    d = {"key" : "sudh" , 1:[2,3,4,5]}
    print(d["key2"])
    
except KeyError as e :
    print(e)
# Out:
# 'key2'

# %%
try :
    "Panakaj".test()
except AttributeError as e :
    print(e)
# Out:
# 'str' object has no attribute 'test'

# %%
try :
    l =[2,3,4,5]
    print(l[6])
except IndexError as e :
    print(e)
# Out:
# list index out of range

# %%
try :
    123+ "Harshita"

except TypeError as e :
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try :
    with open("test.txt" , 'r') as f:
        
      test = f.read()
except Exception as e :
    print(e)
    
except FileNotFoundError as e :
    print("test" ,e)
# Out:
# [Errno 2] No such file or directory: 'test.txt'

# %%
def test(file):
    
    
  try :  
    with open("test.txt" , 'r') as f:
        
      test = f.read()
except Exception as e :
    print(e)
    
except FileNotFoundError as e :
    print("test" ,e)
# Out:
#   Cell In[32], line 8
#     except Exception as e :
#                            ^
# SyntaxError: expected 'except' or 'finally' block

# %% [markdown]
# ##Best  Practice Exception Handing

# %%
#always try a specific exception
try :
    10/0
except Exception as e :
    print(e)
# Out:
# division by zero

# %%
try :
    10/0
except ZeroDivisionError as e :
    print("I am trying to handle a zerodivisior error" , e)
# Out:
# I am trying to handle a zerodivisior error division by zero

# %%
#always try to log your error
import logging
logging.basicConfig(filename ="error.log" , level =logging.ERROR)

try :
    10/0
except ZeroDivisionError as e :
    logging.error("i am trying to handle a zerodivisior error {} ".format(e))

# %%
#Document all the error
#cleanup all the resources

try :
    with open("test.txt" ,'w') as f :
        f.write("this is my data to file")
except FileNotFoundError as e:
    logging.error("i am handling file not found {}".format(e) )
finally :
    f.close()
