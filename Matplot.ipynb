# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [2,3,4,5,6]

plt.plot(x,y)

# %%
x = np.linspace(0,10, 200) #create x data used this function

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y=np.sin(x) #create data used this function

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y ,'--b')
plt.figure(figsize = (8,4))
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()
plt.grid()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.12071617, 0.42184688, 0.21921563, 0.66122196, 0.04067202,
#        0.68336221, 0.47208699, 0.01354507, 0.57275827, 0.56769834,
#        0.58023792, 0.11762405, 0.3252017 , 0.57254938, 0.69215469,
#        0.10833067, 0.22736703, 0.66065927, 0.44134551, 0.97817879,
#        0.26508852, 0.67502405, 0.10864957, 0.64492603, 0.76203833,
#        0.7825957 , 0.33212826, 0.89932898, 0.43390635, 0.56911366,
#        0.83312726, 0.82872648, 0.25258767, 0.38731936, 0.69921662,
#        0.95724584, 0.94954237, 0.37229048, 0.86104264, 0.03615943,
#        0.56423029, 0.50541784, 0.6598256 , 0.65651709, 0.335437  ,
#        0.91443108, 0.47925532, 0.04705798, 0.47995689, 0.50256154])

# %%
y
# Out:
# array([0.68711964, 0.33736374, 0.02850079, 0.23112118, 0.71930956,
#        0.70121313, 0.74500356, 0.57471113, 0.25332668, 0.88356566,
#        0.2321935 , 0.39450766, 0.50602089, 0.1154103 , 0.56086063,
#        0.59309036, 0.2740513 , 0.33881344, 0.32069255, 0.35617267,
#        0.08489256, 0.12438445, 0.75625764, 0.66131814, 0.57664298,
#        0.61267954, 0.28017369, 0.61195585, 0.81182083, 0.9028987 ,
#        0.26385362, 0.69295527, 0.62980646, 0.32572682, 0.35614881,
#        0.02259733, 0.15111792, 0.7755581 , 0.74703059, 0.05929725,
#        0.00127343, 0.46961851, 0.14930948, 0.08843918, 0.12399987,
#        0.08412868, 0.60173347, 0.35140114, 0.45257104, 0.04644543])

# %%
colours = np.random.rand(50)
sizes = 300*np.random.rand(50)
plt.scatter(x,y , c = colours , s = sizes ,alpha = 0.5)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = ['a' ,'b' ,'c' ,'d' ,'e']

# %%
y = np.random.rand(5)
plt.bar(x,y)
plt.xlabel("x axis")
plt.ylabel("y  axis")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
y
# Out:
# array([0.18160744, 0.53762095, 0.64988417, 0.44058782, 0.48651875])

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
plt.barh(x,y)
plt.xlabel("x axis")
plt.ylabel("y  axis")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
x = np.random.rand(50)
y = np.random.rand(50)

colours = np.random.rand(50)
sizes = 300*np.random.rand(50)
plt.scatter(x,y , c = 'blue' , s = sizes ,alpha = 0.5 , marker = 'v')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x ,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.plot(x ,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.scatter(x ,y)
plt.show()

# %%
data = [1,2,3,4,5,1,2,3,6,8,1,2,3]

plt.hist(data)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.scatter(x,y , color = "blue")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = "3d")
ax.scatter(x,y,z)
plt.show()
