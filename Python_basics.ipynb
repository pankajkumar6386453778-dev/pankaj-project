# %%
1+2
# Out:
# 3

# %%
a =int(input("enter first number :" ))
b = int(input("enter second number :" ))

print(a*b , a-b , a+b, a/b ,a*a)
# Out:
# enter first number : 776
# enter second number : 765
# 593640 11 1541 1.0143790849673202 602176

# %%
a = 89
b = 85
c = a*b
print(c)
# Out:
# 7565

# %%
pankaj = 20

# %%
a+pankaj
# Out:
# 109

# %%
type(a)
# Out:
# int

# %%
type(pankaj)
# Out:
# int

# %%
b = 2.09

# %%
type(b)
# Out:
# float

# %%
d = "Pankaj"

# %%
print(d)
# Out:
# Pankaj

# %%
type(d)
# Out:
# str

# %%
e = "This is my first tech class"

# %%
print(e)
# Out:
# This is my first tech class

# %%
type(e)
# Out:
# str

# %%
n = True

# %%
type(n)
# Out:
# bool

# %%
m = False

# %%
type(m)
# Out:
# bool

# %%
n+m
# Out:
# 1

# %%
True *True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
v =5 +8j

# %%
type(v)
# Out:
# complex

# %%
v.real
# Out:
# 5.0

# %%
v.imag
# Out:
# 8.0

# %%
v
# Out:
# (5+8j)

# %%
print(" Hey My Name is Pankaj!")
# Out:
#  Hey My Name is Pankaj!

# %%
print(a)
# Out:
# 89

# %%
s = "pwskills"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'p'

# %%
s[2]
# Out:
# 's'

# %%
s[3]
# Out:
# 'k'

# %%
s[-1]
# Out:
# 's'

# %%
s[-8]
# Out:
# 'p'

# %%
s[0:3]
# Out:
# 'pws'

# %%
s[::-1] # print reverse direction
# Out:
# 'sllikswp'

# %%
s[0:8]
# Out:
# 'pwskills'

# %%
#alternate data  concept
s[0:8:2]
# Out:
# 'psil'

# %%
s[0:4:1]
# Out:
# 'pwsk'

# %%
#second Ways
s[::2]
# Out:
# 'psil'

# %%
s[2::2]
# Out:
# 'sil'

# %%
s[2::1]
# Out:
# 'skills'

# %%
s[::-1] # print in reverse direction
# Out:
# 'sllikswp'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'slliksw'

# %%
c = 200

# %%
s1 = "this is my string class"

# %%
len(s1)
# Out:
# 23

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find("i")
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
s1.find("iS")
# Out:
# -1

# %%
s1.count("s")
# Out:
# 5

# %%
s1.count("st")
# Out:
# 1

# %%
s1.count("z")
# Out:
# 0

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2 = 'THIS IS MY STRING CLASS'

# %%
s2.lower()
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s
# Out:
# 'pwskills'

# %%
s + s1
# Out:
# 'pwskillsthis is my string class'

# %%
s + "Harshita"
# Out:
# 'pwskillsHarshita'

# %%
s +"234" # convert into string first
# Out:
# 'pwskills234'

# %%
s * 3
# Out:
# 'pwskillspwskillspwskills'

# %%
"Harshita" * 65
# Out:
# '...'

# %%
"don't do copy or paste in my class"
# Out:
# "don't do copy or paste in my class"

# %%
s3 ="This is my first class for programming"

# %%
len(s3)
# Out:
# 38

# %%
"""# This is a multi-line comment
# It is written using multiple
# single-line comment symbols"""
# Out:
# '# This is a multi-line comment\n# It is written using multiple\n# single-line comment symbols'

# %%
"""# 1 Once upon a time, there was a boy named Pankaj
# 2 He was a curious Computer Science student
# 3 He loved coding and learning new technologies
# 4 Every day, he opened his laptop with excitement
# 5 He started his journey with Python programming
# 6 At first, everything looked confusing
# 7 But he did not give up
# 8 He practiced daily with determination
# 9 Slowly, he began to understand concepts
# 10 Comments helped him explain his code

# 11 One day, he decided to build an AI assistant
# 12 He imagined it talking like a human
# 13 He named it "Zara"
# 14 Zara could answer questions and help him study
# 15 Pankaj wrote simple programs first
# 16 Then he improved them step by step
# 17 Errors came, but he fixed them patiently
# 18 Debugging became his daily routine
# 19 He learned from every mistake
# 20 His confidence started growing"""
# Out:
# '# 1 Once upon a time, there was a boy named Pankaj\n# 2 He was a curious Computer Science student\n# 3 He loved coding and learning new technologies\n# 4 Every day, he opened his laptop with excitement\n# 5 He started his journey with Python programming\n# 6 At first, everything looked confusing\n# 7 But he did not give up\n# 8 He practiced daily with determination\n# 9 Slowly, he began to understand concepts\n# 10 Comments helped him explain his code\n\n# 11 One day, he decided to build an AI assistant\n# 12 He imagined it talking like a human\n# 13 He named it "Zara"\n# 14 Zara could answer questions and help him study\n# 15 Pankaj wrote simple programs first\n# 16 Then he improved them step by step\n# 17 Errors came, but he fixed them patiently\n# 18 Debugging became his daily routine\n# 19 He learned from every mistake\n# 20 His confidence started growing'
