# %%
#oops = object oriented programming

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("pwskills"))
# Out:
# <class 'str'>

# %%
#create class
class test :
    pass

# %%
a =  test()

# %%
type(a)
# Out:
# __main__.test

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class pwskills :
    def welcome_msg(self):
        print("Welcome pw skills")

# %%
rohan = pwskills()

# %%
print(type(rohan))
# Out:
# <class '__main__.pwskills'>

# %%
rohan.welcome_msg()
# Out:
# Welcome pw skills

# %%
pankaj= pwskills()

# %%
pankaj.welcome_msg()
# Out:
# Welcome pw skills

# %%
class pwskills :

    def __init__(self , phone_number ,email_id ,student_id):
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id = student_id
    def return_student_details(self):
        return self.student_id , self.phone_number ,self.email_id

# %%
rohan = pwskills()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 rohan = pwskills()
#
# TypeError: pwskills.__init__() missing 3 required positional arguments: 'phone_number', 'email_id', and 'student_id'

# %%
rohan = pwskills(903892828 , "rohan@gmail.com" , 102)

# %%
rohan.return_student_details()
# Out:
# (102, 903892828, 'rohan@gmail.com')

# %%
rohan.phone_number
# Out:
# 903892828

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
class pwskills1 :

    def __init__(self , phone_number ,email_id ,student_id):
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id = student_id
    def return_student_details(self):
        return self.student_id , self.phone_number ,self.email_id

# %%
Harshita = pwskills1(903738393, "harshita@gmail.com", 199)

# %%
Harshita.return_student_details()
# Out:
# (199, 903738393, 'harshita@gmail.com')

# %%
class pwskills2:

    def __init__(self , phone_number ,email_id ,student_id):
        self.phone_number1 = phone_number
        self.email_id1 = email_id
        self.student_id1 = student_id
    def return_student_details(self):
        return self.student_id1 , self.phone_number1 ,self.email_id1

# %%
sudh = pwskills2(909837376, "sudh@gmail.com" , 345)

# %%
sudh.phone_number1
# Out:
# 909837376

# %%
sudh.email_id1
# Out:
# 'sudh@gmail.com'

# %%
sudh.return_student_details()
# Out:
# (345, 909837376, 'sudh@gmail.com')

# %%
class pwskills2 :
#self is not a reserved keyword
    def __init__(sudh , phone_number ,email_id ,student_id):
        sudh.phone_number = phone_number
        sudh.email_id = email_id
        sudh.student_id = student_id
    def return_student_details(sudh):
        return sudh.student_id , sudh.phone_number ,sudh.email_id

# %%
rohan = pwskills2(89003938374 , "rohan@gmail.com" , 890)

# %%
rohan.phone_number
# Out:
# 89003938374

# %%
rohan.return_student_details()
# Out:
# (890, 89003938374, 'rohan@gmail.com')

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
print(rohan.student_id)
# Out:
# 890

# %%
#INHERITANCE
class test :
    def test_meth(self):
        return "this is my first class"

# %%
class child_test(test) :
    pass

# %%
child_test_obj = child_test()

# %%
child_test_obj.test_meth()
# Out:
# 'this is my first class'

# %%
class class1 :
    def test_class1(self):
        return "this is a meth from class1"

# %%
class class2(class1) :
    def test_class2(self):
        return "this is a meth from class2"

# %%
class class3(class2) :
    pass

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# 'this is a meth from class1'

# %%
obj_class3.test_class2()
# Out:
# 'this is a meth from class2'

# %%
#multiple inheritance
class class1 :
    def test_class1(self):
        return "this is s class1"

# %%
class class2 :
    def test_class2(self):
        return "this is class2"

# %%
class class3(class1 ,class2):
    pass

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# 'this is s class1'

# %%
obj_class3.test_class2()
# Out:
# 'this is class2'

# %%
#POLYMORPHISM
def test(a , b) :
    return a+b

# %%
test(783737,8337774)
# Out:
# 9121511

# %%
test("Harshita" , "Pankaj")
# Out:
# 'HarshitaPankaj'

# %%
test([2,3,4,5] ,[9,3,4,3])
# Out:
# [2, 3, 4, 5, 9, 3, 4, 3]

# %%
class data_science :

    def syllabus(self):
        print("this is my syllabus for datascience masters")

# %%
class web_dev:
    def syllabus(self):
        print("thsi is syllabus for web dev")

# %%
def class_parcer(class_obj):
    for i in class_obj:
        i.syllabus()

# %%
data_science = data_science()

# %%
web_dev = web_dev()

# %%
class_obj = [data_science ,web_dev]

# %%
class_parcer(class_obj)
# Out:
# this is my syllabus for datascience masters
# thsi is syllabus for web dev

# %%
#ENCAPSULATION
class test :

    def __init__(self , a, b):
        
       self.a = a
       self.b = b

# %%
t = test(23 ,34)

# %%
t.a =83738

# %%
t.a
# Out:
# 83738

# %%
class car :
    def __init__(self , year , make , model ,speed) :

        self.__year = year #hide the data used this concept/private the data
        self.__make = make
        self.__model = model
        self.__speed = 0

    def set_speed(self ,speed) :
        self.__speed = 0 if speed < 0 else speed

    def get_speed(self):
        return self.__speed

# %%
c = car(2021 , "toyota", "innova" , 12)

# %%
c

# %%
c._car__year #access this ways
# Out:
# 2021

# %%
c.set_speed(-3245)

# %%
c.get_speed()
# Out:
# 0

# %%
c.set_speed(234)

# %%
c.get_speed()
# Out:
# 234

# %%
class bank_account:
    def __init__(self , balance) :
        self.__balance = balance

    def deposit(self ,amount) :
        self.__balance = self.__balance+amount

    def withdraw(self , amount) :
        if self.__balance >= amount:
            self.__balance = self.__balance -amount
            return True
        else :
            return False

    def get_balance(self) :
        return self.__balance

# %%
sudh = bank_account(1000)

# %%
sudh.get_balance()
# Out:
# 1000

# %%
sudh.deposit(5000)

# %%
sudh.get_balance()
# Out:
# 6000

# %%
sudh.deposit(9000)

# %%
sudh.get_balance()
# Out:
# 15000

# %%
sudh.withdraw(16000)
# Out:
# False

# %%
sudh.withdraw(9000)
# Out:
# True

# %%
sudh.get_balance()
# Out:
# 6000

# %%
#DECORATOR
def test():
    print("this is start of my function")
    print(4+5)
    print("this is my fun to tests")
    print("this is the end of my function")

# %%
test()
# Out:
# this is start of my function
# 9
# this is my fun to tests
# this is the end of my function

# %%
def deco(func):
    def inner_dec():
        
       print("this is start of my function")
       func()
       
       print("this is the end of my function")

    return inner_dec

# %%
@deco
def test1():
    print(6+7)

# %%
test1()
# Out:
# this is start of my function
# 13
# this is the end of my function

# %%
# !pip install timer

# %%
import time

def timer_test(func):
    def timer_test_inner():
        start = time.time()
        func()
        end = time.time()
        print(end - start)
        return timer_test_inner

# %%
def test2():
    print(45+78)

# %%
test2()
# Out:
# 123

# %%
@timer_test
def test2():
    print(45+78)

# %%
test2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 test2()
#
# TypeError: 'NoneType' object is not callable

# %%
@timer_test
def test():
    for i in range(100000000):
        pass

# %%
test()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[198], line 1
# ----> 1 test()
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# #CLASS METHOD

# %%
#Class method
class pwskills :

    def __init__(self , name ,email) :
        self.name = name
        self.email = email

    def students_details(self):
        print(self.name , self.email)

# %%
pw = pwskills("mohan" ,"mohan@gmail.com")

# %%
pw.name
# Out:
# 'mohan'

# %%
pw.email
# Out:
# 'mohan@gmail.com'

# %%
pw.students_details()
# Out:
# mohan mohan@gmail.com

# %%
class pwskills1:

    def __init__(self , name ,email) :
        self.name = name
        self.email = email
        
    @classmethod   
    def details(cls , name ,email):
        return cls(name ,email)

    def students_details(self):
        print(self.name , self.email)

# %%
pw1= pwskills1.details("sudh" , "sudh@gmail.com")

# %%
pw1.email
# Out:
# 'sudh@gmail.com'

# %%
pw1.name
# Out:
# 'sudh'

# %%
pw1.students_details()
# Out:
# sudh sudh@gmail.com

# %%
class pwskills2:
    mobile_num = 9067876738

    def __init__(self , name ,email) :
        self.name = name
        self.email = email
        
    @classmethod
    def change_number(cls ,mobile):
        pwskills2.mobile_num = mobile

    @classmethod
    def details(cls , name ,email):
        return cls(name , email)

    def students_details(self):
        print(self.name , self.email ,pwskills2.mobile_num)

# %%
pwskills2.mobile_num
# Out:
# 9067876738

# %%
pwskills2.change_number(9039836363)

# %%
pwskills2.mobile_num
# Out:
# 9039836363

# %%
pw_obj = pwskills2("sudh" , "sudh@gmail.com")

# %%
pw_obj.students_details()
# Out:
# sudh sudh@gmail.com 9039836363

# %%
pw = pwskills2.details("rohan", "rohan@gmail.com")#class method

# %%
pw.students_details()
# Out:
# rohan rohan@gmail.com 9039836363

# %%
class pwskills3:
    mobile_num = 9067876738

    def __init__(self , name ,email) :
        self.name = name
        self.email = email
        
    @classmethod
    def change_number(cls ,mobile):
        pwskills2.mobile_num = mobile

    @classmethod
    def details(cls , name ,email):
        return cls(name , email)

    def students_details(self):
        print(self.name , self.email ,pwskills2.mobile_num)

# %%
class pwskills3:
    @classmethod
    def course_details(cls , course_name) :#external function
       print("course name is " , course_name)

# %%
pwskills3.cousre_details = classmethod(course_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pwskills3.cousre_details = classmethod(course_details)
#
# NameError: name 'course_details' is not defined

# %%
pwskills3.course_details("data science masters")
# Out:
# course name is  data science masters

# %%
class pwskills3:
    @classmethod
    def  mentor(cls , list_of_mentor) :
        print(list_of_mentor)

# %%
pwskills3.mentor = classmethod(mentor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pwskills3.mentor = classmethod(mentor)
#
# NameError: name 'mentor' is not defined

# %%
pwskills3.mentor(["sudhanshu" , "krish naik"])
# Out:
# ['sudhanshu', 'krish naik']

# %% [markdown]
# ##STATIC METHOD

# %%
#static method
class pwskills :
    def student_details(self , name , mail_id , number) :
        print(name , mail_id , number)

# %%
pw = pwskills()

# %%
pw.student_details("sudh" ,"sudh@gmail.com" ,90987645646)
# Out:
# sudh sudh@gmail.com 90987645646

# %%
class pwskills1 :
    def student_details(self , name , mail_id , number) :
        print(name , mail_id , number) #static method

    @staticmethod
    def mentor_class(list_mentor) :
        print(list_mentor)

    def mentor(self ,mentor_list):
        print(mentor_list)

# %%
pwskills1.mentor_class(["sudh" , "krish"])
# Out:
# ['sudh', 'krish']

# %%
stu1 = pwskills1()

# %%
stu1.mentor(["sudh" , "krish"])
# Out:
# ['sudh', 'krish']

# %%
class pwskills2 :
    def student_details(self , name , mail_id , number) :
        print(name , mail_id , number) #static method

    @staticmethod
    def mentor_class(list_mentor) :
        print(mail_id_mentor)

    @staticmethod
    def mentor_class(list_mentor) :
        pwskills.mentor_mail_id(["sudh@gmail.com" ,"krish@gmail.com"])
        print(list_mentor)

    @classmethod
    def class_name(cls):
        cls.mentor_class(["sudh" , "krish"])

    def mentor(self ,mentor_list):
        print(mentor_list)

# %%
pwskills2.mentor_class(["krish" , "sudh"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pwskills2.mentor_class(["krish" , "sudh"])
#
# Cell In[35], line 11, in pwskills2.mentor_class(list_mentor)
#       9     @staticmethod
#      10     def mentor_class(list_mentor) :
# ---> 11         pwskills.mentor_mail_id(["sudh@gmail.com" ,"krish@gmail.com"])
#      12         print(list_mentor)
#
# AttributeError: type object 'pwskills' has no attribute 'mentor_mail_id'

# %%
pwskills2.class_name(cls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pwskills2.class_name(cls)
#
# NameError: name 'cls' is not defined

# %% [markdown]
# #special(magic and dunder)

# %%
#Dunder method
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
a =100

# %%
a+ 5
# Out:
# 105

# %%
a.__add__(5)
# Out:
# 105

# %%
a.__mul__(78)
# Out:
# 7800

# %%
a.__sub__(35)
# Out:
# 65

# %%
class pwskills :
    def __new__(cls) :
        print("this is my new")
        
    def __init__(self):
        
        print("this is my init")

        self.mobile_number = 9048376353

# %%
pw =pwskills()
# Out:
# this is my new

# %%
class pwskills1 :
        
    def __init__(self):

        self.mobile_number = 9048376353
        
    def __str__(self):
        return "this is my magic call of str"

# %%
pw1 = pwskills1()

# %%
pw1

# %%
print(pw1)
# Out:
# this is my magic call of str
