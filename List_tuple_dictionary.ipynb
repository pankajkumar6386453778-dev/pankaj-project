# %% [markdown]
# #List data type

# %%
#List
l = [1,2,3,7  ,"Harshita" , True , 5+7j , 4664.998]

# %%
print(l)
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
# Out:
# (5+7j)

# %%
l[4]
# Out:
# 'Harshita'

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[-1]
# Out:
# 4664.998

# %%
l[::-1]  #used reverse the list
# Out:
# [4664.998, (5+7j), True, 'Harshita', 7, 3, 2, 1]

# %%
l[::2]
# Out:
# [1, 3, 'Harshita', (5+7j)]

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998]

# %%
s = "pwskills"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s) +l
# Out:
# ['p',
#  'w',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  1,
#  2,
#  3,
#  7,
#  'Harshita',
#  True,
#  (5+7j),
#  4664.998]

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998]

# %%
l[4]
# Out:
# 'Harshita'

# %%
type(l[4])
# Out:
# str

# %%
l[4][0:2]
# Out:
# 'Ha'

# %%
str(l[5])[0:2]
# Out:
# 'Tr'

# %%
l+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1= [3,4,5]

# %%
l+l1
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998, 3, 4, 5]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998]

# %%
len(l)
# Out:
# 8

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998]

# %%
l.append(5) #add any no in the last used append function

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998, 5]

# %%
l.append(s)

# %%
s
# Out:
# 'pwskills'

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998, 5, 'pwskills']

# %%
l1
# Out:
# [3, 4, 5]

# %%
l.append(l1)

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998, 5, 'pwskills', [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l
# Out:
# [1, 2, 3, 7, 'Harshita', True, (5+7j), 4664.998, 5, 'pwskills', [3, 4, 5]]

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("Pankaj") #when used fn used first iterables data

# %%
l
# Out:
# [1,
#  2,
#  3,
#  7,
#  'Harshita',
#  True,
#  (5+7j),
#  4664.998,
#  5,
#  'pwskills',
#  [3, 4, 5],
#  'P',
#  'a',
#  'n',
#  'k',
#  'a',
#  'j']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  2,
#  3,
#  7,
#  'Harshita',
#  True,
#  (5+7j),
#  4664.998,
#  5,
#  'pwskills',
#  [3, 4, 5],
#  'P',
#  'a',
#  'n',
#  'k',
#  'a',
#  'j',
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(1,"Harshita")

# %%
l1
# Out:
# [3, 'Harshita', 4, 5]

# %%
l1.insert(2 ,[2,3,4])

# %%
l1
# Out:
# [3, 'Harshita', [2, 3, 4], 4, 5]

# %%
l1.insert(-1 ,45)

# %%
l1
# Out:
# [45, 3, 'Harshita', 4]

# %%
l1.insert(0 ,45)

# %%
l1
# Out:
# [45, 3, 'Harshita', [2, 3, 4], 4, 45, 5]

# %%
l1.pop() #used for delete fronm last index
# Out:
# 5

# %%
l1
# Out:
# [45, 3, 'Harshita', [2, 3, 4], 4, 45]

# %%
l1
# Out:
# [45, 3, 'Harshita', [2, 3, 4], 4, 45]

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 3, 'Harshita', [2, 3, 4], 4]

# %%
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 3, 'Harshita', 4]

# %%
l1[::-1]
# Out:
# [4, 'Harshita', 3, 45]

# %%
l1.reverse()

# %%
l1
# Out:
# [4, 'Harshita', 3, 45]

# %%
l2 = [3,4,5,71,2,9,0,6,543,2,32]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 2, 2, 3, 4, 5, 6, 9, 32, 71, 543]

# %%
l3 = [34,90,4774,4746,8483]

# %%
l3.sort()

# %%
l3
# Out:
# [34, 90, 4746, 4774, 8483]

# %%
l4 = ["Panakj" , "Harshita" , "Tanmay", "Satakshi"]

# %%
l4.sort(reverse=True)#descending order

# %%
l4
# Out:
# ['Tanmay', 'Satakshi', 'Panakj', 'Harshita']

# %%
l4.index("Panakj")
# Out:
# 2

# %%
l4.count("Harshita")
# Out:
# 1

# %%
s = "sudh"

# %%
l5 =[3,4,56]

# %%
s[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 s[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0] = 39

# %%
l5
# Out:
# [39, 4, 56]

# %%
s
# Out:
# 'sudh'

# %%
s.replace('s' ,'a')
# Out:
# 'audh'

# %% [markdown]
# ##Tuple

# %%
#tuples
t = (2,3,4,5, "sudh",45.56 ,False ,45+457j ,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
t[0]="sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 t[0]="sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(5)
# Out:
# 1

# %%
t.index(False)
# Out:
# 6

# %% [markdown]
# ##Sets

# %%
##sets
s1 = {}

# %%
type(s1)
# Out:
# dict

# %%
s2 = {2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={334,322,445,"Pankaj",45+98j,45.89,(2,3,4)}

# %%
s3
# Out:
# {(2, 3, 4), (45+98j), 322, 334, 445, 45.89, 'Pankaj'}

# %%
s4 ={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh" , "sudh"}

# %%
s4 # set remove all duplicate element
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6 ={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh" , "sudh"}

# %%
l6=list(set(l6))

# %%
l6
# Out:
# [1, 2, 3, 4, 5, 6, 'sudh', 'Sudh']

# %%
s5 = {234,45,23,12,567,45,2,789,234,"abc",456,342,23}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5.remove(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}
